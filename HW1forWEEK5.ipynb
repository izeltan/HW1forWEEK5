# %%
#HOMEWORK 1:Web Site inputs

# %%
import bs4
import pandas as pd
import requests

# %%
response = requests.get('https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db')
print(response.text) # Print the output
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Spotify Tracks DB | Kaggle</title>
#     <meta charset="utf-8" />
#     <meta name="robots" content="index, follow" />
#     <meta name="description" content="Music database (232k tracks) key, mode and time signature are cleaned" />
#     <meta name="turbolinks-cache-control" content="no-cache" />
#         <meta name="keywords" content="arts and entertainment,online media,music,music streams and downloads,statistical analysis" />
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#     <meta name="theme-color" content="#008ABC" />
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#         window["initialPageLoadStartTime"] = new Date().getTime();
#     </script>
#     <link rel="preconnect" href="https://www.google-analytics.com" crossorigin="anonymous" /><link rel="preconnect" href="https://stats.g.doubleclick.net" /><link rel="preconnect" href="https://js.intercomcdn.com" /><link rel="preconnect" href="https://storage.googleapis.com" /><link rel="preconnect" href="https://apis.google.com" /><link rel="preload" href="/static/assets/fontawesome-webfont.woff2" as="font" crossorigin="anonymous" />
#     <link href="/static/images/favicon.ico" rel="shortcut icon" type="image/x-icon" />
#     <link rel="manifest" href="/static/json/manifest.json" crossorigin="use-credentials">
#     <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic" rel='stylesheet' type='text/css'>
#     <link href="https://fonts.googleapis.com/icon?family=Google+Material+Icons" rel="stylesheet" type='text/css' />
#         <link rel="stylesheet" type="text/css" href="/static/assets/vendor.css?v=3091c404ef1de61ee968" />
#         <link rel="stylesheet" type="text/css" href="/static/assets/app.css?v=7347f48563b0202d54f6" />
#
#
#
#         <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#         try{(function(a,s,y,n,c,h,i,d,e){d=s.createElement("style");
#         d.appendChild(s.createTextNode(""));s.head.appendChild(d);d=d.sheet;
#         y=y.map(x => d.insertRule(x + "{ opacity: 0 !important }"));
#         h.start=1*new Date;h.end=i=function(){y.forEach(x => x<d.cssRules.length ? d.deleteRule(x) : {})};
#         (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#         })(window,document,['.site-header-react__nav'],'dataLayer',2000,{'GTM-52LNT9S':true});}catch(ex){}
#     </script>
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#         gtag('config', 'UA-12629138-1', {
#             'optimize_id': 'GTM-52LNT9S',
#             'displayFeaturesTask': null,
#             'send_page_view': false
#         });
#     </script>
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==" async src="https://www.googletagmanager.com/gtag/js?id=UA-12629138-1"></script>
#
#
#
#         <meta property="og:url" content="https://kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db" />
#         <meta property="og:title" content="Spotify Tracks DB" />
#         <meta property="og:description" content="Music database (232k tracks) key, mode and time signature are cleaned" />
#         <meta property="og:type" content="website" />
#         <meta property="og:image" content="https://storage.googleapis.com/kaggle-datasets-images/135088/320840/87b7c1feeef2b6a837da5084f5a27511/dataset-card.png?t=2019-03-09-18-09-52" />
#         <meta property="fb:app_id" content="2665027677054710" />
#
#
#         <meta name="twitter:card" content="summary" />
#         <meta name="twitter:site" content="@kaggledatasets" />
#             <meta name="twitter:creator" content="@ZaheenHamidani" />
#
#
#
#
#         <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="application/ld+json">{"@context":"http://schema.org/","@type":"Dataset","name":"Spotify Tracks DB","description":"### Context\n\nI just wanted to analyze the behavior between valence and all the measures that Spotify API gives so I got approximately 10,000 per genre. There are 26 genres so it is a total of 232,725 tracks.\n\n### Content\n\nThis is the explanation of every measure: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/\n\n### Acknowledgements\n\nI want to say thanks to https://www.kaggle.com/tomigelo because I used his code to get these tracks.\n\nThere is the code: https://github.com/tgel0/spotify-data","url":"https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db","sameAs":"","version":3,"keywords":["culture and arts, arts and entertainment","culture and arts, arts and entertainment, online media","culture and arts, performing arts, music","culture and arts, performing arts, music, music streams and downloads","analysis, statistical analysis"],"license":{"@type":"CreativeWork","name":"Unknown","url":""},"identifier":["135088"],"includedInDataCatalog":{"@type":"DataCatalog","name":"Kaggle","url":"https://www.kaggle.com"},"creator":{"@type":"Person","name":"Zaheen Hamidani","url":"https://www.kaggle.com/zaheenhamidani","image":"https://storage.googleapis.com/kaggle-avatars/thumbnails/2525176-kg.jpg"},"distribution":[{"@type":"DataDownload","requiresSubscription":true,"encodingFormat":"zip","fileFormat":"zip","contentUrl":"https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db/download","contentSize":"33709086 bytes"},{"@type":"DataDownload","requiresSubscription":true,"encodingFormat":"csv","fileFormat":"csv","contentUrl":"https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db/download/IedE6Omn2lIW9eIcv3ov%2Fversions%2FSOtXf3vemxBio0JOInDu%2Ffiles%2FSpotifyFeatures.csv?datasetVersionNumber=3","contentSize":"33709086 bytes"}],"commentCount":4,"dateModified":"2019-07-23T04:26:23.773","discussionUrl":"https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db/discussion","alternateName":"Music database (232k tracks) key, mode and time signature are cleaned","isAccessibleForFree":true,"thumbnailUrl":"https://storage.googleapis.com/kaggle-datasets-images/135088/320840/87b7c1feeef2b6a837da5084f5a27511/dataset-card.png?t=2019-03-09-18-09-52","interactionStatistic":[{"@type":"InteractionCounter","interactionType":"http://schema.org/CommentAction","userInteractionCount":4},{"@type":"InteractionCounter","interactionType":"http://schema.org/DownloadAction","userInteractionCount":3397},{"@type":"InteractionCounter","interactionType":"http://schema.org/ViewAction","userInteractionCount":19652},{"@type":"InteractionCounter","interactionType":"http://schema.org/LikeAction","userInteractionCount":94}]}</script>
#
#
#
#
#
# <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#     var Kaggle = Kaggle || {};
#
#     Kaggle.Current = {
#         antiForgeryToken: 'CfDJ8LdUzqlsSWBPr4Ce3rb9VL-6p8j8HflUSZy4loghFgqZv0Dsf2SMEZ7dTH62_-FZ2iaWo3Onl4rU5IZUtCkhwpC7zBbq9_Pl7wLVusVAWLAYUvED3KOFoINW4WqnolZy5TYEztMFNXg8tu6DVVKC-ME',
#         isAnonymous: true,
#         analyticsToken: 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE1ODM4MzAxNzksIlVzZXJJZCI6MH0.ttiCRHjGIqDqLJ476heu-1Cn0yH50GOHA4-URi5tq8o',
#         analyticsTokenExpiry: 15,
#         internetKernelsEnabled: false,
#
#
#
#
#
#
#         mdeImageUploader: true,
#
#
#
#     }
#         Kaggle.Current.log = function(){};
#         Kaggle.Current.warn = function(){};
#
#     var decodeUserDisplayName = function () {
#         var escapedUserDisplayName = Kaggle.Current.userDisplayNameEscaped || "";
#         try {
#             var textVersion = new DOMParser().parseFromString(escapedUserDisplayName, "text/html").documentElement.textContent;
#             if (textVersion) {
#                 return textVersion;
#             }
#         } catch(ex) {}
#         return escapedUserDisplayName;
#     }
#     Kaggle.Current.userDisplayName = decodeUserDisplayName();
# </script>
#
#
#
# <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#     var Kaggle = Kaggle || {};
#     Kaggle.PageMessages = [];
# </script>
#
#         <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
# /* <![CDATA[ */
# goog_snippet_vars = function() {
#     var w = window;
#     w.google_conversion_id = 955616553;
#     w.google_conversion_label = "QSjvCKDksHMQqZrWxwM";
#     w.google_conversion_value = 0.00;
#     w.google_conversion_currency = "USD";
#     w.google_remarketing_only = false;
#     w.google_conversion_language = "en";
#     w.google_conversion_format = "3";
#     w.google_conversion_color = "ffffff";
# }
# // DO NOT CHANGE THE CODE BELOW.
# goog_report_conversion = function(url) {
#     goog_snippet_vars();
#     window.google_conversion_format = "3";
#     var opt = new Object();
#     opt.onload_callback = function() {
#         if (typeof(url) != 'undefined') {
#             window.location = url;
#         }
#     }
#     var conv_handler = window['google_trackConversion'];
#     if (typeof(conv_handler) == 'function') {
#         conv_handler(opt);
#     }
# }
# /* ]]> */
#     </script>
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript"
#             src="//www.googleadservices.com/pagead/conversion_async.js">
#     </script>
#
#
#
#         <script nonce="XiE6EibsByFtzS3vo1CJrQ==">window['useKaggleAnalytics'] = true;</script>
#
#     <script id="gapi-target" nonce="XiE6EibsByFtzS3vo1CJrQ==" src="https://apis.google.com/js/api.js" defer async></script>
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==" src="/static/assets/runtime.js?v=c167930caa407b8937e7" data-turbolinks-track="reload"></script>
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==" src="/static/assets/vendor.js?v=850d4c0387f70162606d" data-turbolinks-track="reload"></script>
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==" src="/static/assets/app.js?v=e9765fa26cf8121e727f" data-turbolinks-track="reload"></script>
#         <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#             (function() {
#                 if ('serviceWorker' in navigator) {
#                     navigator.serviceWorker.register("/static/assets/service-worker.js").then(function(reg) {
#                         reg.onupdatefound = function() {
#                             var installingWorker = reg.installing;
#                             installingWorker.onstatechange = function() {
#                                 switch (installingWorker.state) {
#                                 case 'installed':
#                                     if (navigator.serviceWorker.controller) {
#                                         console.log('New or updated content is available.');
#                                     } else {
#                                         console.log('Content is now available offline!');
#                                     }
#                                     break;
#                                 case 'redundant':
#                                     console.error('The installing service worker became redundant.');
#                                     break;
#                                 }
#                             };
#                         };
#                     }).catch(function(e) {
#                       console.error('Error during service worker registration:', e);
#                     });
#                 }
#             })();
#         </script>
#         <script nonce="XiE6EibsByFtzS3vo1CJrQ==" defer src="https://cdn.jsdelivr.net/npm/stackdriver-errors-js@0.7.0/dist/stackdriver-errors-concat.min.js"></script>
#         <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#             window.addEventListener('DOMContentLoaded', function () {
#                 var errorHandler = new StackdriverErrorReporter();
#                 errorHandler.start({
#                     key: 'AIzaSyDANGXFHtSIVc51MIdGwg4mQFgm3oNrKoo',
#                     projectId: 'kaggle-161607',
#                     service: 'web-fe',
#                     version: '58a31d8fb347bfcde58166090dca04fd8432e8e6',
#                     context: {
#                         user: '0',
#                     },
#                 });
#             });
#         </script>
# </head>
# <body data-turbolinks="false">
#     <main>
#
#
#
#
#
#
#
# <div id="site-container"></div>
# <div data-component-name="NavigationContainer" style="display: flex; flex-direction: column; flex: 1 0 auto;"></div><script nonce="XiE6EibsByFtzS3vo1CJrQ==">var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"isTopNavigation":false});performance && performance.mark && performance.mark("NavigationContainer.componentCouldBootstrap");</script>
# <div id="site-body" class="hide">
#
#
#
# <div data-component-name="DatasetContainer" style="display: flex; flex-direction: column; flex: 1 0 auto;"></div><script nonce="XiE6EibsByFtzS3vo1CJrQ==">var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"scripts":[],"discussions":[],"pageMessages":[],"discussion":{"canDownvote":false,"dataUrl":"/forums/145283/topics.json","id":145283,"isRootLevel":false,"showSubscribeButton":false,"isSubscribed":false,"subscription":"unsubscribe","initialTopics":null,"paramValues":{"category":"all","page":1,"search":null,"group":"all","sortBy":"hot"}},"currentTab":"home","newTopic":{"allowAttachments":false,"authorRanking":null,"authorTier":"novice","authorType":"topic","forumId":145283,"parentName":"Spotify Tracks DB","parentUrl":"/zaheenhamidani/ultimate-spotify-tracks-db"},"categories":{"type":"dataset","tags":[{"displayName":"arts and entertainment","fontAwesomeIcon":"","id":2200,"name":"arts and entertainment","fullPath":"culture and arts \u003e arts and entertainment","listingUrl":"/datasets?group=public\u0026tagids=2200","description":"Activities that holds the attention and interest of an audience, or gives pleasure and delight. It can be an idea or a task, but is more likely to be one of the activities or events that have developed over thousands of years specifically for the purpose of keeping an audience\u0027s attention.","isInherited":false,"datasetCount":3289,"competitionCount":0,"scriptCount":10,"totalCount":3299,"tagUrl":"/tags/arts-and-entertainment"},{"displayName":"online media","fontAwesomeIcon":"","id":16099,"name":"online media","fullPath":"culture and arts \u003e arts and entertainment \u003e online media","listingUrl":"/datasets?group=public\u0026tagids=16099","description":null,"isInherited":false,"datasetCount":744,"competitionCount":0,"scriptCount":0,"totalCount":744,"tagUrl":"/tags/online-media"},{"displayName":"music","fontAwesomeIcon":"","id":2304,"name":"music","fullPath":"culture and arts \u003e performing arts \u003e music","listingUrl":"/datasets?group=public\u0026tagids=2304","description":"With all the music data out there, it\u0027s hard to believe someone hasn\u0027t trained robots to perform on stage yet. Or have they?","isInherited":false,"datasetCount":643,"competitionCount":0,"scriptCount":47,"totalCount":690,"tagUrl":"/tags/music"},{"displayName":"music streams and downloads","fontAwesomeIcon":"","id":16166,"name":"music streams and downloads","fullPath":"culture and arts \u003e performing arts \u003e music \u003e music streams and downloads","listingUrl":"/datasets?group=public\u0026tagids=16166","description":null,"isInherited":false,"datasetCount":79,"competitionCount":0,"scriptCount":0,"totalCount":79,"tagUrl":"/tags/music-streams-and-downloads"},{"displayName":"statistical analysis","fontAwesomeIcon":"","id":13210,"name":"statistical analysis","fullPath":"analysis \u003e statistical analysis","listingUrl":"/datasets?group=public\u0026tagids=13210","description":null,"isInherited":false,"datasetCount":40,"competitionCount":0,"scriptCount":194,"totalCount":234,"tagUrl":"/tags/statistical-analysis"}]},"upvoteSuggestion":{"voteCount":94,"medalVoteCount":15,"upVoteUrl":"/zaheenhamidani/ultimate-spotify-tracks-db/vote","upVoters":[{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1160082-kg.jpg","displayName":"Shahebaz","profileUrl":"/shaz13","tier":"Master","tierInt":3,"userId":1160082,"userName":"shaz13"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1351163-kg.jpeg","displayName":"Tarun Paparaju","profileUrl":"/tarunpaparaju","tier":"Master","tierInt":3,"userId":1351163,"userName":"tarunpaparaju"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1920818-kg.JPG","displayName":"Prashant Banerjee","profileUrl":"/prashant111","tier":"Master","tierInt":3,"userId":1920818,"userName":"prashant111"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/2082203 ...
#     MathJax.Hub.Config({
#     "HTML-CSS": {
#     preferredFont: "TeX",
#     availableFonts: ["STIX", "TeX"],
#     linebreaks: {
#     automatic: true
#     },
#     EqnChunk: (MathJax.Hub.Browser.isMobile ? 10 : 50)
#     },
#     tex2jax: {
#     inlineMath: [["\\(", "\\)"], ["\\\\(", "\\\\)"]],
#     displayMath: [["$$", "$$"], ["\\[", "\\]"]],
#     processEscapes: true,
#     ignoreClass: "tex2jax_ignore|dno"
#     },
#     TeX: {
#     noUndefined: {
#     attributes: {
#     mathcolor: "red",
#     mathbackground: "#FFEEEE",
#     mathsize: "90%"
#     }
#     }
#     },
#     Macros: {
#     href: "{}"
#     },
#     skipStartupTypeset: true,
#     messageStyle: "none"
#     });
# </script>
# <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript" async crossorigin="anonymous" src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.0/MathJax.js?config=TeX-AMS-MML_HTMLorMML"></script>
#
#
# </div>
#
#
#
#
#     </main>
# </body>
# </html>

# %%
soup = bs4.BeautifulSoup(response.text, "html.parser")
print(soup.prettify()) # Print the output using the 'prettify' function cleaner
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Spotify Tracks DB | Kaggle
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="Music database (232k tracks) key, mode and time signature are cleaned" name="description"/>
#   <meta content="no-cache" name="turbolinks-cache-control"/>
#   <meta content="arts and entertainment,online media,music,music streams and downloads,statistical analysis" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="#008ABC" name="theme-color">
#    <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#     window["initialPageLoadStartTime"] = new Date().getTime();
#    </script>
#    <link crossorigin="anonymous" href="https://www.google-analytics.com" rel="preconnect"/>
#    <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#    <link href="https://js.intercomcdn.com" rel="preconnect"/>
#    <link href="https://storage.googleapis.com" rel="preconnect"/>
#    <link href="https://apis.google.com" rel="preconnect"/>
#    <link as="font" crossorigin="anonymous" href="/static/assets/fontawesome-webfont.woff2" rel="preload"/>
#    <link href="/static/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link crossorigin="use-credentials" href="/static/json/manifest.json" rel="manifest"/>
#    <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic" rel="stylesheet" type="text/css"/>
#    <link href="https://fonts.googleapis.com/icon?family=Google+Material+Icons" rel="stylesheet" type="text/css">
#     <link href="/static/assets/vendor.css?v=3091c404ef1de61ee968" rel="stylesheet" type="text/css">
#      <link href="/static/assets/app.css?v=7347f48563b0202d54f6" rel="stylesheet" type="text/css"/>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#       try{(function(a,s,y,n,c,h,i,d,e){d=s.createElement("style");
#         d.appendChild(s.createTextNode(""));s.head.appendChild(d);d=d.sheet;
#         y=y.map(x => d.insertRule(x + "{ opacity: 0 !important }"));
#         h.start=1*new Date;h.end=i=function(){y.forEach(x => x<d.cssRules.length ? d.deleteRule(x) : {})};
#         (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#         })(window,document,['.site-header-react__nav'],'dataLayer',2000,{'GTM-52LNT9S':true});}catch(ex){}
#      </script>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#       window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#         gtag('config', 'UA-12629138-1', {
#             'optimize_id': 'GTM-52LNT9S',
#             'displayFeaturesTask': null,
#             'send_page_view': false
#         });
#      </script>
#      <script async="" nonce="XiE6EibsByFtzS3vo1CJrQ==" src="https://www.googletagmanager.com/gtag/js?id=UA-12629138-1">
#      </script>
#      <meta content="https://kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db" property="og:url"/>
#      <meta content="Spotify Tracks DB" property="og:title"/>
#      <meta content="Music database (232k tracks) key, mode and time signature are cleaned" property="og:description"/>
#      <meta content="website" property="og:type"/>
#      <meta content="https://storage.googleapis.com/kaggle-datasets-images/135088/320840/87b7c1feeef2b6a837da5084f5a27511/dataset-card.png?t=2019-03-09-18-09-52" property="og:image"/>
#      <meta content="2665027677054710" property="fb:app_id"/>
#      <meta content="summary" name="twitter:card"/>
#      <meta content="@kaggledatasets" name="twitter:site"/>
#      <meta content="@ZaheenHamidani" name="twitter:creator"/>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="application/ld+json">
#       {"@context":"http://schema.org/","@type":"Dataset","name":"Spotify Tracks DB","description":"### Context\n\nI just wanted to analyze the behavior between valence and all the measures that Spotify API gives so I got approximately 10,000 per genre. There are 26 genres so it is a total of 232,725 tracks.\n\n### Content\n\nThis is the explanation of every measure: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/\n\n### Acknowledgements\n\nI want to say thanks to https://www.kaggle.com/tomigelo because I used his code to get these tracks.\n\nThere is the code: https://github.com/tgel0/spotify-data","url":"https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db","sameAs":"","version":3,"keywords":["culture and arts, arts and entertainment","culture and arts, arts and entertainment, online media","culture and arts, performing arts, music","culture and arts, performing arts, music, music streams and downloads","analysis, statistical analysis"],"license":{"@type":"CreativeWork","name":"Unknown","url":""},"identifier":["135088"],"includedInDataCatalog":{"@type":"DataCatalog","name":"Kaggle","url":"https://www.kaggle.com"},"creator":{"@type":"Person","name":"Zaheen Hamidani","url":"https://www.kaggle.com/zaheenhamidani","image":"https://storage.googleapis.com/kaggle-avatars/thumbnails/2525176-kg.jpg"},"distribution":[{"@type":"DataDownload","requiresSubscription":true,"encodingFormat":"zip","fileFormat":"zip","contentUrl":"https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db/download","contentSize":"33709086 bytes"},{"@type":"DataDownload","requiresSubscription":true,"encodingFormat":"csv","fileFormat":"csv","contentUrl":"https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db/download/IedE6Omn2lIW9eIcv3ov%2Fversions%2FSOtXf3vemxBio0JOInDu%2Ffiles%2FSpotifyFeatures.csv?datasetVersionNumber=3","contentSize":"33709086 bytes"}],"commentCount":4,"dateModified":"2019-07-23T04:26:23.773","discussionUrl":"https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db/discussion","alternateName":"Music database (232k tracks) key, mode and time signature are cleaned","isAccessibleForFree":true,"thumbnailUrl":"https://storage.googleapis.com/kaggle-datasets-images/135088/320840/87b7c1feeef2b6a837da5084f5a27511/dataset-card.png?t=2019-03-09-18-09-52","interactionStatistic":[{"@type":"InteractionCounter","interactionType":"http://schema.org/CommentAction","userInteractionCount":4},{"@type":"InteractionCounter","interactionType":"http://schema.org/DownloadAction","userInteractionCount":3397},{"@type":"InteractionCounter","interactionType":"http://schema.org/ViewAction","userInteractionCount":19652},{"@type":"InteractionCounter","interactionType":"http://schema.org/LikeAction","userInteractionCount":94}]}
#      </script>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#       var Kaggle = Kaggle || {};
#
#     Kaggle.Current = {
#         antiForgeryToken: 'CfDJ8LdUzqlsSWBPr4Ce3rb9VL-6p8j8HflUSZy4loghFgqZv0Dsf2SMEZ7dTH62_-FZ2iaWo3Onl4rU5IZUtCkhwpC7zBbq9_Pl7wLVusVAWLAYUvED3KOFoINW4WqnolZy5TYEztMFNXg8tu6DVVKC-ME',
#         isAnonymous: true,
#         analyticsToken: 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE1ODM4MzAxNzksIlVzZXJJZCI6MH0.ttiCRHjGIqDqLJ476heu-1Cn0yH50GOHA4-URi5tq8o',
#         analyticsTokenExpiry: 15,
#         internetKernelsEnabled: false,
#
#
#
#
#
#
#         mdeImageUploader: true,
#
#
#
#     }
#         Kaggle.Current.log = function(){};
#         Kaggle.Current.warn = function(){};
#
#     var decodeUserDisplayName = function () {
#         var escapedUserDisplayName = Kaggle.Current.userDisplayNameEscaped || "";
#         try {
#             var textVersion = new DOMParser().parseFromString(escapedUserDisplayName, "text/html").documentElement.textContent;
#             if (textVersion) {
#                 return textVersion;
#             }
#         } catch(ex) {}
#         return escapedUserDisplayName;
#     }
#     Kaggle.Current.userDisplayName = decodeUserDisplayName();
#      </script>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#       var Kaggle = Kaggle || {};
#     Kaggle.PageMessages = [];
#      </script>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#       /* <![CDATA[ */
# goog_snippet_vars = function() {
#     var w = window;
#     w.google_conversion_id = 955616553;
#     w.google_conversion_label = "QSjvCKDksHMQqZrWxwM";
#     w.google_conversion_value = 0.00;
#     w.google_conversion_currency = "USD";
#     w.google_remarketing_only = false;
#     w.google_conversion_language = "en";
#     w.google_conversion_format = "3";
#     w.google_conversion_color = "ffffff";
# }
# // DO NOT CHANGE THE CODE BELOW.
# goog_report_conversion = function(url) {
#     goog_snippet_vars();
#     window.google_conversion_format = "3";
#     var opt = new Object();
#     opt.onload_callback = function() {
#         if (typeof(url) != 'undefined') {
#             window.location = url;
#         }
#     }
#     var conv_handler = window['google_trackConversion'];
#     if (typeof(conv_handler) == 'function') {
#         conv_handler(opt);
#     }
# }
# /* ]]> */
#      </script>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#      </script>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#       window['useKaggleAnalytics'] = true;
#      </script>
#      <script async="" defer="" id="gapi-target" nonce="XiE6EibsByFtzS3vo1CJrQ==" src="https://apis.google.com/js/api.js">
#      </script>
#      <script data-turbolinks-track="reload" nonce="XiE6EibsByFtzS3vo1CJrQ==" src="/static/assets/runtime.js?v=c167930caa407b8937e7">
#      </script>
#      <script data-turbolinks-track="reload" nonce="XiE6EibsByFtzS3vo1CJrQ==" src="/static/assets/vendor.js?v=850d4c0387f70162606d">
#      </script>
#      <script data-turbolinks-track="reload" nonce="XiE6EibsByFtzS3vo1CJrQ==" src="/static/assets/app.js?v=e9765fa26cf8121e727f">
#      </script>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#       (function() {
#                 if ('serviceWorker' in navigator) {
#                     navigator.serviceWorker.register("/static/assets/service-worker.js").then(function(reg) {
#                         reg.onupdatefound = function() {
#                             var installingWorker = reg.installing;
#                             installingWorker.onstatechange = function() {
#                                 switch (installingWorker.state) {
#                                 case 'installed':
#                                     if (navigator.serviceWorker.controller) {
#                                         console.log('New or updated content is available.');
#                                     } else {
#                                         console.log('Content is now available offline!');
#                                     }
#                                     break;
#                                 case 'redundant':
#                                     console.error('The installing service worker became redundant.');
#                                     break;
#                                 }
#                             };
#                         };
#                     }).catch(function(e) {
#                       console.error('Error during service worker registration:', e);
#                     });
#                 }
#             })();
#      </script>
#      <script defer="" nonce="XiE6EibsByFtzS3vo1CJrQ==" src="https://cdn.jsdelivr.net/npm/stackdriver-errors-js@0.7.0/dist/stackdriver-errors-concat.min.js">
#      </script>
#      <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/javascript">
#       window.addEventListener('DOMContentLoaded', function () {
#                 var errorHandler = new StackdriverErrorReporter();
#                 errorHandler.start({
#                     key: 'AIzaSyDANGXFHtSIVc51MIdGwg4mQFgm3oNrKoo',
#                     projectId: 'kaggle-161607',
#                     service: 'web-fe',
#                     version: '58a31d8fb347bfcde58166090dca04fd8432e8e6',
#                     context: {
#                         user: '0',
#                     },
#                 });
#             });
#      </script>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body data-turbolinks="false">
#   <main>
#    <div id="site-container">
#    </div>
#    <div data-component-name="NavigationContainer" style="display: flex; flex-direction: column; flex: 1 0 auto;">
#    </div>
#    <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#     var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"isTopNavigation":false});performance && performance.mark && performance.mark("NavigationContainer.componentCouldBootstrap");
#    </script>
#    <div class="hide" id="site-body">
#     <div data-component-name="DatasetContainer" style="display: flex; flex-direction: column; flex: 1 0 auto;">
#     </div>
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==">
#      var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"scripts":[],"discussions":[],"pageMessages":[],"discussion":{"canDownvote":false,"dataUrl":"/forums/145283/topics.json","id":145283,"isRootLevel":false,"showSubscribeButton":false,"isSubscribed":false,"subscription":"unsubscribe","initialTopics":null,"paramValues":{"category":"all","page":1,"search":null,"group":"all","sortBy":"hot"}},"currentTab":"home","newTopic":{"allowAttachments":false,"authorRanking":null,"authorTier":"novice","authorType":"topic","forumId":145283,"parentName":"Spotify Tracks DB","parentUrl":"/zaheenhamidani/ultimate-spotify-tracks-db"},"categories":{"type":"dataset","tags":[{"displayName":"arts and entertainment","fontAwesomeIcon":"","id":2200,"name":"arts and entertainment","fullPath":"culture and arts \u003e arts and entertainment","listingUrl":"/datasets?group=public\u0026tagids=2200","description":"Activities that holds the attention and interest of an audience, or gives pleasure and delight. It can be an idea or a task, but is more likely to be one of the activities or events that have developed over thousands of years specifically for the purpose of keeping an audience\u0027s attention.","isInherited":false,"datasetCount":3289,"competitionCount":0,"scriptCount":10,"totalCount":3299,"tagUrl":"/tags/arts-and-entertainment"},{"displayName":"online media","fontAwesomeIcon":"","id":16099,"name":"online media","fullPath":"culture and arts \u003e arts and entertainment \u003e online media","listingUrl":"/datasets?group=public\u0026tagids=16099","description":null,"isInherited":false,"datasetCount":744,"competitionCount":0,"scriptCount":0,"totalCount":744,"tagUrl":"/tags/online-media"},{"displayName":"music","fontAwesomeIcon":"","id":2304,"name":"music","fullPath":"culture and arts \u003e performing arts \u003e music","listingUrl":"/datasets?group=public\u0026tagids=2304","description":"With all the music data out there, it\u0027s hard to believe someone hasn\u0027t trained robots to perform on stage yet. Or have they?","isInherited":false,"datasetCount":643,"competitionCount":0,"scriptCount":47,"totalCount":690,"tagUrl":"/tags/music"},{"displayName":"music streams and downloads","fontAwesomeIcon":"","id":16166,"name":"music streams and downloads","fullPath":"culture and arts \u003e performing arts \u003e music \u003e music streams and downloads","listingUrl":"/datasets?group=public\u0026tagids=16166","description":null,"isInherited":false,"datasetCount":79,"competitionCount":0,"scriptCount":0,"totalCount":79,"tagUrl":"/tags/music-streams-and-downloads"},{"displayName":"statistical analysis","fontAwesomeIcon":"","id":13210,"name":"statistical analysis","fullPath":"analysis \u003e statistical analysis","listingUrl":"/datasets?group=public\u0026tagids=13210","description":null,"isInherited":false,"datasetCount":40,"competitionCount":0,"scriptCount":194,"totalCount":234,"tagUrl":"/tags/statistical-analysis"}]},"upvoteSuggestion":{"voteCount":94,"medalVoteCount":15,"upVoteUrl":"/zaheenhamidani/ultimate-spotify-tracks-db/vote","upVoters":[{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1160082-kg.jpg","displayName":"Shahebaz","profileUrl":"/shaz13","tier":"Master","tierInt":3,"userId":1160082,"userName":"shaz13"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1351163-kg.jpeg","displayName":"Tarun Paparaju","profileUrl":"/tarunpaparaju","tier":"Master","tierInt":3,"userId":1351163,"userName":"tarunpaparaju"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1920818-kg.JPG","displayName":"Prashant Banerjee","profileUrl":"/prashant111","tier":"Master","tierInt":3,"userId":1920818,"userName":"prashant111"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/2082203-kg.jpg","displayName":"Ahmad Javed","profileUrl":"/ahmadjaved097","tier":"Expert","tierInt":2,"userId":2082203,"userName":"ahmadjaved097"},{"avatarT ...
#     </script>
#     <script nonce="XiE6EibsByFtzS3vo1CJrQ==" type="text/x-mathjax-config">
#      MathJax.Hub.Config({
#     "HTML-CSS": {
#     preferredFont: "TeX",
#     availableFonts: ["STIX", "TeX"],
#     linebreaks: {
#     automatic: true
#     },
#     EqnChunk: (MathJax.Hub.Browser.isMobile ? 10 : 50)
#     },
#     tex2jax: {
#     inlineMath: [["\\(", "\\)"], ["\\\\(", "\\\\)"]],
#     displayMath: [["$$", "$$"], ["\\[", "\\]"]],
#     processEscapes: true,
#     ignoreClass: "tex2jax_ignore|dno"
#     },
#     TeX: {
#     noUndefined: {
#     attributes: {
#     mathcolor: "red",
#     mathbackground: "#FFEEEE",
#     mathsize: "90%"
#     }
#     }
#     },
#     Macros: {
#     href: "{}"
#     },
#     skipStartupTypeset: true,
#     messageStyle: "none"
#     });
#     </script>
#     <script async="" crossorigin="anonymous" nonce="XiE6EibsByFtzS3vo1CJrQ==" src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.0/MathJax.js?config=TeX-AMS-MML_HTMLorMML" type="text/javascript">
#     </script>
#    </div>
#   </main>
#  </body>
# </html>

# %%
# Access the title element
soup.title
# Out:
# <title>Spotify Tracks DB | Kaggle</title>

# %%
# Access the content of the title element
soup.title.string
# Out:
# 'Spotify Tracks DB | Kaggle'

# %%
# Access data in the first 'p' tag
soup.div
# Out:
# <div id="site-container"></div>

# %%
data = soup.findAll(attrs={'class':'DataTable_Cell-sc-1d2l9ix DataTable_TableCell-sc-13l0208 loOctw'}#calısmyoooor
for i in data:
    print(i.string)

# %%
print #####cvs import
# Out:
# <function print>

# %%
f = open('SpotifyFeatures.csv','a') # open new file, make sure path to your data file is correct

p = 0 # initial place in array
l = len(data)-1 # length of array minus one


f.write("County, State, FIPS Code, Total Pop, Median Income ($), No. of Housing Units, Median Home Value ($), No. of Owner Occupied Housing Units, No. of Owner Occ. Housing Units with Debt, No. of Owner Occ. Housing Units without Debt\n") #write headers


while p < l: # while place is less than length
    f.write(data[p].string + ", ") # write county and add comma
    p = p + 1 # increment
    f.write(data[p].string + ", ") # write FIPS and add comma
    p = p + 1 # increment
    f.write(data[p].string + ", ") # write Total Pop and add comma
    p = p + 1 # increment
    f.write(data[p].string + ", ") # write Median Income and add comma
    p = p + 1 # increment
    f.write(data[p].string + ", ") # write No. of Housing Units and add comma
    p = p + 1 # increment
    f.write(data[p].string + ", ") # write Median Home Value and add comma
    p = p + 1 # increment
    f.write(data[p].string + ", ") # write No. of Owner Occupied Housing Units and add comma
    p = p + 1 # increment
    f.write(data[p].string + ", ") # write No. of Owner Occ. Housing Units with Debt and add comma
    p = p + 1 # increment
    f.write(data[p].string + "\n") # write No. of Owner Occ. Housing Units without Debt and line break
    p = p + 1 # increment

    
f.close() # close file
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-7fb9ff4231b9> in <module>
#       3 p = 0 # initial place in array
#       4 l = len(data)-1 # length of array minus one
# ----> 5 f.write(l)
#       6
#       7 f.write("County, State, FIPS Code, Total Pop, Median Income ($), No. of Housing Units, Median Home Value ($), No. of Owner Occupied Housing Units, No. of Owner Occ. Housing Units with Debt, No. of Owner Occ. Housing Units without Debt\n") #write headers
#
# TypeError: write() argument must be str, not int

# %%
spoti = pd.read_csv('SpotifyFeatures.csv')
# Out:
# C:\Users\efay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
spoti.shape
# Out:
# (232729, 18)

# %%
spoti
# Out:
#          genre        artist_name                        track_name  \
# 0        Movie     Henri Salvador       C'est beau de faire un Show
# 1        Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2        Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3        Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4        Movie       Fabien Nataf                         Ouverture
# ...        ...                ...                               ...
# 232724    Soul     Mint Condition    You Don't Have To Hurt No More
# 232725  County              State                         FIPS Code
# 232726  County              State                         FIPS Code
# 232727  County              State                         FIPS Code
# 232728  County              State                         FIPS Code
#
#                       track_id          popularity           acousticness  \
# 0       0BRjO6ga9RKCKjfDqeFgWV                   0                  0.611
# 1       0BjC1NfoEOOusryehmNudP                   1                  0.246
# 2       0CoSDzoNIKCRs124s9uTVy                   3                  0.952
# 3       0Gc6TVm52BwZD07Ki6tIvf                   0                  0.703
# 4       0IuslXpMROHdEPvSl1fTQK                   4                   0.95
# ...                        ...                 ...                    ...
# 232724  34XO9RwPMKjbvRry54QzWn                  35                 0.0973
# 232725               Total Pop   Median Income ($)   No. of Housing Units
# 232726               Total Pop   Median Income ($)   No. of Housing Units
# 232727               Total Pop   Median Income ($)   No. of Housing Units
# 232728               Total Pop   Median Income ($)   No. of Housing Units
#
#                   danceability                           duration_ms  \
# 0                        0.389                                 99373
# 1                         0.59                                137373
# 2                        0.663                                170267
# 3                         0.24                                152427
# 4                        0.331                                 82625
# ...                        ...                                   ...
# 232724                   0.758                                323027
# 232725   Median Home Value ($)   No. of Owner Occupied Housing Units
# 232726   Median Home Value ($)   No. of Owner Occupied Housing Units
# 232727   Median Home Value ($)   No. of Owner Occupied Housing Units
# 232728   Median Home Value ($)   No. of Owner Occupied Housing Units
#
#                                             energy  \
# 0                                             0.91
# 1                                            0.737
# 2                                            0.131
# 3                                            0.326
# 4                                            0.225
# ...                                            ...
# 232724                                        0.47
# 232725   No. of Owner Occ. Housing Units with Debt
# 232726   No. of Owner Occ. Housing Units with Debt
# 232727   No. of Owner Occ. Housing Units with Debt
# 232728   No. of Owner Occ. Housing Units with Debt
#
#                                      instrumentalness  key  liveness  \
# 0                                                   0   C#    0.3460
# 1                                                   0   F#    0.1510
# 2                                                   0    C    0.1030
# 3                                                   0   C#    0.0985
# 4                                               0.123    F    0.2020
# ...                                               ...  ...       ...
# 232724                                       4.89e-05   G#    0.0836
# 232725   No. of Owner Occ. Housing Units without Debt  NaN       NaN
# 232726   No. of Owner Occ. Housing Units without Debt  NaN       NaN
# 232727   No. of Owner Occ. Housing Units without Debt  NaN       NaN
# 232728   No. of Owner Occ. Housing Units without Debt  NaN       NaN
#
#         loudness   mode  speechiness    tempo time_signature  valence
# 0         -1.828  Major       0.0525  166.969            4/4    0.814
# 1         -5.559  Minor       0.0868  174.003            4/4    0.816
# 2        -13.879  Minor       0.0362   99.488            5/4    0.368
# 3        -12.178  Major       0.0395  171.758            4/4    0.227
# 4        -21.150  Major       0.0456  140.576            4/4    0.390
# ...          ...    ...          ...      ...            ...      ...
# 232724    -6.708  Minor       0.0287  113.897            4/4    0.479
# 232725       NaN    NaN          NaN      NaN            NaN      NaN
# 232726       NaN    NaN          NaN      NaN            NaN      NaN
# 232727       NaN    NaN          NaN      NaN            NaN      NaN
# 232728       NaN    NaN          NaN      NaN            NaN      NaN
#
# [232729 rows x 18 columns]

# %%
from sklearn import linear_model
from sklearn import metrics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.model_selection import train_test_split

# %%
corrMatrix = spoti.corr()
sn.heatmap(corrMatrix, annot=True)

# %%
spoti.plot(x='popularity', y='danceability', style='o')  
plt.title('popularity vs danceability')  
plt.xlabel('popularity')  
plt.ylabel('danceability')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-87a62cec4875> in <module>
# ----> 1 spoti.plot(x='popularity', y='danceability', style='o')
#       2 plt.title('popularity vsdanceability')
#       3 plt.xlabel('popularity')
#       4 plt.ylabel('danceability')
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     412         # no non-numeric frames or series allowed
#     413         if is_empty:
# --> 414             raise TypeError("no numeric data to plot")
#     415
#     416         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot
